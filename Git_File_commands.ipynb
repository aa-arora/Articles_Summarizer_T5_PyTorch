# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/GitHubProjects/Articles_Summarizer_T5_PyTorch/
# Out:
# /content/drive/MyDrive/GitHubProjects/Articles_Summarizer_T5_PyTorch

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	Data/
# 	Git_File_commands.ipynb
# 	Title_Generation_T5_medium_articles.ipynb
# 	drive/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git config user.email "aakasharora97@gmail.com"
# !git config user.name "aa-arora"
# !git commit -m "Changed DataSet Size - Initial commit"
# Out:
# [master d6e576c] added transformers file
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Git_File_commands.ipynb (93%)

# %%
# !git push
# Out:
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 778.44 KiB | 9.27 MiB/s, done.
# Total 8 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 2 local objects.
# To https://github.com/aa-arora/MSc_project_gousto_recipe_creator
#    ee77019..d6e576c  master -> master
# error: update_ref failed for ref 'refs/remotes/origin/master': cannot lock ref 'refs/remotes/origin/master': Unable to create '/content/drive/MyDrive/MScProject/MSc_project_gousto_recipe_creator/.git/refs/remotes/origin/master.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
