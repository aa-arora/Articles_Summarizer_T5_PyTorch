# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/GitHubProjects/Articles_Summarizer_T5_PyTorch/
# Out:
# /content/drive/MyDrive/GitHubProjects/Articles_Summarizer_T5_PyTorch

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   Git_File_commands.ipynb
# 	new file:   Title_Generation_T5_medium_articles.ipynb

# %%
# !git config user.email "aakasharora97@gmail.com"
# !git config user.name "aa-arora"
# !git commit -m "Changed DataSet Size - Initial commit"
# Out:
# [main 9f10297] Changed DataSet Size - Initial commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 Git_File_commands.ipynb
#  create mode 100644 Title_Generation_T5_medium_articles.ipynb

# %%
# !git push
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 2.98 MiB | 4.72 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# To https://github.com/aa-arora/Articles_Summarizer_T5_PyTorch
#    3da3387..9f10297  main -> main
